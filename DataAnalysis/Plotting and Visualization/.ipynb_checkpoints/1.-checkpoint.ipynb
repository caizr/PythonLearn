# %% [markdown]
# # API入门

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data=np.arange(5)
plt.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
#matplotlib图像都位于Figure对象中，用plt.figure创建一个新的Figure
fig = plt.figure()
ax1=fig.add_subplot(2,2,1)
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
#画出来的在上面显示，代表2行2列，第二幅图
ax2=fig.add_subplot(2,2,2)

# %%
#第三幅图
ax3=fig.add_subplot(2,2,3)

# %%
#这时执行一条绘图命令，matplotlib会在最后一个用过的subplot(如果没有则创建一个)
#上进行绘制

#k--是一个线形选项，告诉码头plotlib绘制黑色虚线图
plt.plot(np.random.randn(50).cumsum(),'k--')

# %%
#上面由fig.add_subplot所返回的对象是  AxesSubplot 对象，直接调用它们的实例
#方法就可以在其他空着的格子里面画图！
ax1.hist(np.random.randn(100),bins=20,color='k',alpha=0.3)
# Out:
# (array([ 2.,  1.,  0.,  1.,  3.,  5.,  3.,  8.,  7.,  8.,  8., 11., 12.,
#          7.,  9.,  5.,  4.,  3.,  1.,  2.]),
#  array([-2.81315604, -2.55575204, -2.29834803, -2.04094403, -1.78354002,
#         -1.52613601, -1.26873201, -1.011328  , -0.753924  , -0.49651999,
#         -0.23911598,  0.01828802,  0.27569203,  0.53309603,  0.79050004,
#          1.04790404,  1.30530805,  1.56271206,  1.82011606,  2.07752007,
#          2.33492407]),
#  <a list of 20 Patch objects>)

# %%
#还有一个更方便的方法plt.subplots，它可以创建⼀个新的Figure，并返回⼀个含有
#已创建的subplot对象的NumPy数组
fig,axes=plt.subplots(2,3)
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DB4EBC4320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DB4E79C6D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DB4F7EEAC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DB4F8307B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DB4F6A9438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DB4FDAC550>]],
#       dtype=object)

# %%
#?????????????这里我还不懂！！！！
axes[1,1]=plt.plot([2,3,3])
plt.subplots_adjust(left=None, bottom=None, right=None, top=None,
wspace=None, hspace=None)
