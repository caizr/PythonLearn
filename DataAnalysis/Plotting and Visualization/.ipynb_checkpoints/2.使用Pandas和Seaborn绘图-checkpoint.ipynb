# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 线型图

# %%
s=pd.Series(np.random.randn(50).cumsum(),index=np.arange(50))
xt=np.arange(10,60)

# %%
#Series方法直接绘图
s.plot(label='a',xticks=(10,20,30),yticks=(-6,-4,-5),xlim=[0,70],ylim=(-10,1),grid=True)

# %% [markdown]
# #### 参数说明

# %% [markdown]
# <img src="png\2.png" width="90%">
# <img src="png\2-1.png" width="90%">

# %% [markdown]
# #### pandas大部分绘图方法都有一个可选的ax参数！可以是一个subplot对象！！

# %%
df=pd.DataFrame(np.random.randn(50).reshape(5,10),index=list
                ('abcde'))
df.plot(xticks=[2,4])

# %% [markdown]
# #### `df.plot()等价于de.plot.line()

# %% [markdown]
# #### DataFrame还有⼀些用于对列进行灵活处理的选项，例如，是要将所有列都绘制到⼀个subplot中还是创建各⾃的subplot。详细信息请参见表9-4。

# %% [markdown]
# <img src="png\3.png" width="90%">
# <img src="png\3-1.png" width="90%">

# %%
df.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001A7DE4B4128>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A7DE4EB4E0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A7DE51C940>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A7DE54FDA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A7DE58D208>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A7DE5C1668>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A7DE5F2AC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A7DE624F60>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A7DE624F98>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A7DE692828>],
#       dtype=object)

# %% [markdown]
# ## 柱状图

# %% [markdown]
# #### plot.bar()和plot.barn()分别绘制水平和垂直的柱状图。此时，Series和DataFrame的索引将会被用作X(bar)和Y(barn)刻度

# %%
#注意这里fig和axes！！
fig,axes=plt.subplots(2,1)
data=pd.Series(np.random.rand(16),index=list('abcdefghijklmnop'))
data.plot.bar(ax=axes[0],color='k',alpha=0.7)
data.plot.barh(ax=axes[1],color='r',alpha=0.7)

# %% [markdown]
# #### 对于DataFrame，柱状图将每一行分为一组

# %%
#注意pd.Index !!!!!!!
df2=pd.DataFrame(np.random.rand(16).reshape(4,4),index=
                 ['one','two','three','four',
                 ],columns=pd.Index(['A','B','C','D'],name='Genus'))
df2.plot.bar()

# %%
df2
# Out:
# Genus         A         B         C         D
# one    0.136497  0.176882  0.924897  0.835258
# two    0.123163  0.625081  0.660649  0.277301
# three  0.296976  0.777881  0.821143  0.683294
# four   0.958479  0.112993  0.453911  0.197040

# %% [markdown]
# #### 生成堆积柱状图

# %%
df2.plot.barh(stacked=True,alpha=0.5)

# %% [markdown]
# #### 柱状图有一个不错的用法：利用value_counts图形化显示Series中各值出现的频率，比如s.value_counts().plot.bar()

# %%
s2=pd.Series([1,3,1,2,4,3,4,3,1,2,1,2,4])
s2.value_counts().plot.bar(color='r',alpha=0.5)
