% %%
a=[1 2 3]
% Out:
% a =
%
%      1     2     3

% %%
Modu=comm.QPSKModulator()
% Out:
% Modu =
%
%   comm.QPSKModulator - 属性:
%
%        PhaseOffset: 0.7854
%           BitInput: false
%      SymbolMapping: 'Gray'
%     OutputDataType: 'double'

% %%
plot([1 2 3])
